# %%
from llmops_datacollection.domain.documents import UserDocument
# Out:
# ---------------------------------------------------------------------------
# PydanticUserError                         Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from llmops_datacollection.domain.documents import UserDocument
#
# File ~/Desktop/noobLLMOPS/llmops_datacollection/llmops_datacollection/__init__.py:5
#       1 """LLMOps Data Collection module."""
#       3 __version__ = "0.1.0"
# ----> 5 from llmops_datacollection import application, domain, infrastructure
#       6 from llmops_datacollection.settings import settings
#       8 __all__ = ["settings", "application", "domain", "infrastructure"]
#
# File ~/Desktop/noobLLMOPS/llmops_datacollection/llmops_datacollection/application/__init__.py:1
# ----> 1 from . import crawlers, utils
#       3 __all__ = ["crawlers", "utils"]
#
# File ~/Desktop/noobLLMOPS/llmops_datacollection/llmops_datacollection/application/crawlers/__init__.py:1
# ----> 1 from .base import BaseCrawler, BaseSeleniumCrawler
#       2 from .dispatcher import CrawlerDispatcher
#       3 from .github import GithubCrawler
#
# File ~/Desktop/noobLLMOPS/llmops_datacollection/llmops_datacollection/application/crawlers/base.py:9
#       6 from selenium import webdriver
#       7 from selenium.webdriver.chrome.options import Options
# ----> 9 from llmops_datacollection.domain.base import NoSQLBaseDocument
#      11 # Install chromedriver if needed
#      12 chromedriver_autoinstaller.install()
#
# File ~/Desktop/noobLLMOPS/llmops_datacollection/llmops_datacollection/domain/__init__.py:1
# ----> 1 from .base import NoSQLBaseDocument
#       2 from .documents import ArticleDocument, PostDocument, RepositoryDocument, UserDocument
#       3 from .exceptions import (
#       4     CrawlerError,
#       5     DatabaseError,
#    (...)
#       8     ValidationError,
#       9 )
#
# File ~/Desktop/noobLLMOPS/llmops_datacollection/llmops_datacollection/domain/base.py:10
#       7 from pymongo import errors
#       9 from llmops_datacollection.domain.exceptions import ImproperlyConfigured
# ---> 10 from llmops_datacollection.infrastructure.db.mongo import connection
#      12 T = TypeVar("T", bound="NoSQLBaseDocument")
#      14 class NoSQLBaseDocument(BaseModel, ABC):
#
# File ~/Desktop/noobLLMOPS/llmops_datacollection/llmops_datacollection/infrastructure/db/mongo.py:9
#       6 from pymongo.errors import ConnectionFailure
#       8 from llmops_datacollection.domain.exceptions import DatabaseError
# ----> 9 from llmops_datacollection.settings import settings
#      11 class MongoDBConnector:
#      12     """MongoDB connection manager."""
#
# File ~/Desktop/noobLLMOPS/llmops_datacollection/llmops_datacollection/settings.py:4
#       2 from pydantic_settings import BaseSettings, SettingsConfigDict
# ----> 4 class Settings(BaseSettings):
#       5     """Application settings."""
#       7     model_config = SettingsConfigDict(
#       8         env_file=".env",
#       9         env_file_encoding="utf-8",
#      10         case_sensitive=True
#      11     )
#
# File ~/Desktop/noobLLMOPS/llmops_datacollection/.venv/lib/python3.12/site-packages/pydantic/_internal/_model_construction.py:111, in ModelMetaclass.__new__(mcs, cls_name, bases, namespace, __pydantic_generic_metadata__, __pydantic_reset_parent_namespace__, _create_model_module, **kwargs)
#     108 if bases:
#     109     base_field_names, class_vars, base_private_attributes = mcs._collect_bases_data(bases)
# --> 111     config_wrapper = ConfigWrapper.for_model(bases, namespace, kwargs)
#     112     namespace['model_config'] = config_wrapper.config_dict
#     113     private_attributes = inspect_namespace(
#     114         namespace, config_wrapper.ignored_types, class_vars, base_field_names
#     115     )
#
# File ~/Desktop/noobLLMOPS/llmops_datacollection/.venv/lib/python3.12/site-packages/pydantic/_internal/_config.py:133, in ConfigWrapper.for_model(cls, bases, namespace, kwargs)
#     127     raise PydanticUserError(
#     128         '`model_config` cannot be used as a model field name. Use `model_config` for model configuration.',
#     129         code='model-config-invalid-field-name',
#     130     )
#     132 if config_class_from_namespace and config_dict_from_namespace:
# --> 133     raise PydanticUserError('"Config" and "model_config" cannot be used together', code='config-both')
#     135 config_from_namespace = config_dict_from_namespace or prepare_config(config_class_from_namespace)
#     137 config_new.update(config_from_namespace)
#
# PydanticUserError: "Config" and "model_config" cannot be used together
#
# For further information visit https://errors.pydantic.dev/2.10/u/config-both

# %%
from llmops_datacollection.domain.documents import UserDocument
from llmops_datacollection.settings import settings

# Create a test user
user = UserDocument(
    first_name="Test",
    last_name="User"
)
user.save()

# Verify user was created
retrieved_user = UserDocument.find(first_name="Test")
if retrieved_user:
    print(f"Found user: {retrieved_user.full_name}")
# Out:
# ---------------------------------------------------------------------------
# PydanticUserError                         Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from llmops_datacollection.domain.documents import UserDocument
#       2 from llmops_datacollection.settings import settings
#       4 # Create a test user
#
# File ~/Desktop/noobLLMOPS/llmops_datacollection/llmops_datacollection/__init__.py:5
#       1 """LLMOps Data Collection module."""
#       3 __version__ = "0.1.0"
# ----> 5 from llmops_datacollection import application, domain, infrastructure
#       6 from llmops_datacollection.settings import settings
#       8 __all__ = ["settings", "application", "domain", "infrastructure"]
#
# File ~/Desktop/noobLLMOPS/llmops_datacollection/llmops_datacollection/application/__init__.py:1
# ----> 1 from . import crawlers, utils
#       3 __all__ = ["crawlers", "utils"]
#
# File ~/Desktop/noobLLMOPS/llmops_datacollection/llmops_datacollection/application/crawlers/__init__.py:1
# ----> 1 from .base import BaseCrawler, BaseSeleniumCrawler
#       2 from .dispatcher import CrawlerDispatcher
#       3 from .github import GithubCrawler
#
# File ~/Desktop/noobLLMOPS/llmops_datacollection/llmops_datacollection/application/crawlers/base.py:9
#       6 from selenium import webdriver
#       7 from selenium.webdriver.chrome.options import Options
# ----> 9 from llmops_datacollection.domain.base import NoSQLBaseDocument
#      11 # Install chromedriver if needed
#      12 chromedriver_autoinstaller.install()
#
# File ~/Desktop/noobLLMOPS/llmops_datacollection/llmops_datacollection/domain/__init__.py:1
# ----> 1 from .base import NoSQLBaseDocument
#       2 from .documents import ArticleDocument, PostDocument, RepositoryDocument, UserDocument
#       3 from .exceptions import (
#       4     CrawlerError,
#       5     DatabaseError,
#    (...)
#       8     ValidationError,
#       9 )
#
# File ~/Desktop/noobLLMOPS/llmops_datacollection/llmops_datacollection/domain/base.py:10
#       7 from pymongo import errors
#       9 from llmops_datacollection.domain.exceptions import ImproperlyConfigured
# ---> 10 from llmops_datacollection.infrastructure.db.mongo import connection
#      12 T = TypeVar("T", bound="NoSQLBaseDocument")
#      14 class NoSQLBaseDocument(BaseModel, ABC):
#
# File ~/Desktop/noobLLMOPS/llmops_datacollection/llmops_datacollection/infrastructure/db/mongo.py:9
#       6 from pymongo.errors import ConnectionFailure
#       8 from llmops_datacollection.domain.exceptions import DatabaseError
# ----> 9 from llmops_datacollection.settings import settings
#      11 class MongoDBConnector:
#      12     """MongoDB connection manager."""
#
# File ~/Desktop/noobLLMOPS/llmops_datacollection/llmops_datacollection/settings.py:4
#       2 from pydantic_settings import BaseSettings, SettingsConfigDict
# ----> 4 class Settings(BaseSettings):
#       5     """Application settings."""
#       7     model_config = SettingsConfigDict(
#       8         env_file=".env",
#       9         env_file_encoding="utf-8",
#      10         case_sensitive=True
#      11     )
#
# File ~/Desktop/noobLLMOPS/llmops_datacollection/.venv/lib/python3.12/site-packages/pydantic/_internal/_model_construction.py:111, in ModelMetaclass.__new__(mcs, cls_name, bases, namespace, __pydantic_generic_metadata__, __pydantic_reset_parent_namespace__, _create_model_module, **kwargs)
#     108 if bases:
#     109     base_field_names, class_vars, base_private_attributes = mcs._collect_bases_data(bases)
# --> 111     config_wrapper = ConfigWrapper.for_model(bases, namespace, kwargs)
#     112     namespace['model_config'] = config_wrapper.config_dict
#     113     private_attributes = inspect_namespace(
#     114         namespace, config_wrapper.ignored_types, class_vars, base_field_names
#     115     )
#
# File ~/Desktop/noobLLMOPS/llmops_datacollection/.venv/lib/python3.12/site-packages/pydantic/_internal/_config.py:133, in ConfigWrapper.for_model(cls, bases, namespace, kwargs)
#     127     raise PydanticUserError(
#     128         '`model_config` cannot be used as a model field name. Use `model_config` for model configuration.',
#     129         code='model-config-invalid-field-name',
#     130     )
#     132 if config_class_from_namespace and config_dict_from_namespace:
# --> 133     raise PydanticUserError('"Config" and "model_config" cannot be used together', code='config-both')
#     135 config_from_namespace = config_dict_from_namespace or prepare_config(config_class_from_namespace)
#     137 config_new.update(config_from_namespace)
#
# PydanticUserError: "Config" and "model_config" cannot be used together
#
# For further information visit https://errors.pydantic.dev/2.10/u/config-both
